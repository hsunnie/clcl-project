# %%
# %pip install selenium
# %pip install webdriver-manager
# %pip install requests

# %%
# 민감한 정보
user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhbm9ueW1vdXNfaWQiOiIyMzk0OTk1MjQiLCJpYXQiOjE3MTgyNjM1Mjd9.28gPu5Pg0unm4q3cwMK-CbWLZdtF2Vs6gFiw_FrpQI8'

# %%
import requests
import json

def ably_crawler(user_agent, token):
    """
    user_agent : User-Agent infomation for get request
    token : X-Anonymous-Token information for get request
    """
    url = 'https://api.a-bly.com/api/v2/screens/filter_options/?filter_token=eyJzY3JlZW5faWQiOiAzMiwgImZpeGVkX3F1ZXJ5IjogeyJjYXRlZ29yeV9saXN0W10iOiBbOCwgMTAsIDE3NCwgMjAzLCA1MTcsIDU0MSwgNDY3LCAxNjksIDddfSwgInBhcmVudF9ncm91cF9pZCI6IDR9&category_list%5B%5D=%5B8%2C%2010%2C%20174%2C%20203%2C%20517%2C%20541%2C%20467%2C%20169%2C%207%5D'
    soup = requests.get(url, headers={'User-Agent':user_agent, 'X-Anonymous-Token':token})
    try:
        python_data = json.loads(soup.text)

        # color
        color_cat = python_data['parent_groups'][2]['child_groups'][0]['entity']['possible_items']
        color_list = {'color':[]}
        for i in range(len(color_cat)):
            color_list['color'].append(color_cat[i]['text'])
        
        # item
        item_cat = python_data['parent_groups'][4]['child_groups'][0]['entity']['possible_items']
        item_list = {'item':[]}
        for i in range(len(item_cat)):
            item_list['item'].append(item_cat[i]['text'])

        # detail
        detail_cat = python_data['parent_groups'][4]['child_groups'][1]['entity']['possible_items']
        detail_list = {'detail':[]}
        for i in range(len(detail_cat)):
            detail_list['detail'].append(detail_cat[i]['text'])
        
        # print
        print_cat = python_data['parent_groups'][4]['child_groups'][2]['entity']['possible_items']
        print_list = {'print':[]}
        for i in range(len(print_cat)):
            print_list['print'].append(print_cat[i]['text'])
        
        # texture
        texture_cat = python_data['parent_groups'][4]['child_groups'][3]['entity']['possible_items']
        texture_list = {'texture':[]}
        for i in range(len(texture_cat)):
            texture_list['texture'].append(texture_cat[i]['text'])
        
        # style
        style_cat = python_data['parent_groups'][4]['child_groups'][4]['entity']['possible_items']
        style_list = {'style':[]}
        for i in range(len(style_cat)):
            style_list['style'].append(style_cat[i]['text'])
        
        # length
        length_cat = python_data['parent_groups'][4]['child_groups'][5]['entity']['possible_items']
        length_list = {'length':[]}
        for i in range(len(length_cat)):
            length_list['length'].append(length_cat[i]['text'])

        # sleeve_length
        sleeve_length_cat = python_data['parent_groups'][4]['child_groups'][6]['entity']['possible_items']
        sleeve_length_list = {'sleeve_length':[]}
        for i in range(len(sleeve_length_cat)):
            sleeve_length_list['sleeve_length'].append(sleeve_length_cat[i]['text'])

        # neck_line
        neck_line_cat = python_data['parent_groups'][4]['child_groups'][7]['entity']['possible_items']
        neck_line_list = {'neck_line':[]}
        for i in range(len(neck_line_cat)):
            neck_line_list['neck_line'].append(neck_line_cat[i]['text'])

        # fit
        fit_cat = python_data['parent_groups'][4]['child_groups'][8]['entity']['possible_items']
        fit_list = {'fit':[]}
        for i in range(len(fit_cat)):
            fit_list['fit'].append(fit_cat[i]['text'])
        
        # shape
        shape_cat = python_data['parent_groups'][4]['child_groups'][9]['entity']['possible_items']
        shape_list = {'shape':[]}
        for i in range(len(shape_cat)):
            shape_list['shape'].append(shape_cat[i]['text'])
        
        return {**color_list, **item_list, **item_list, **detail_list, **print_list, **texture_list, **style_list, **length_list, **sleeve_length_list, **neck_line_list, **fit_list, **shape_list}
        
    except:
        print('crawling error')

# %%
ably_crawler(user_agent, token)
# Out:
# {'color': ['블랙',
#   '화이트',
#   '그레이',
#   '블루',
#   '브라운',
#   '베이지',
#   '핑크',
#   '그린',
#   '스카이블루',
#   '네이비',
#   '옐로우',
#   '퍼플',
#   '레드',
#   '라벤더',
#   '데님',
#   '카키',
#   '오렌지',
#   '민트',
#   '와인',
#   '호피',
#   '기타',
#   '실버',
#   '골드'],
#  'item': ['스웨터',
#   '청바지',
#   '스웨트팬츠',
#   '스웨트셔츠',
#   '셔츠원피스',
#   '니트원피스',
#   '와이드팬츠',
#   '슬립드레스',
#   '스커트',
#   '폴로셔츠',
#   '드레스',
#   '탱크탑',
#   '바람막이',
#   '카고팬츠',
#   '모피코트',
#   '청반바지',
#   '치노팬츠',
#   '튜닉원피스',
#   '브라탑',
#   '멜빵원피스',
#   '자켓',
#   '항공점퍼',
#   '테일러드자켓',
#   '트럼펫스커트',
#   '트렌치코트',
#   '튜브탑',
#   '터틀넥',
#   '랩코트',
#   '파자마',
#   '숄더백',
#   '토트백',
#   '싱글버튼자켓',
#   '야상',
#   '멜빵바지',
#   '데님자켓',
#   '무스탕',
#   '가죽자켓',
#   '숏자켓',
#   '튤스커트',
#   '싱글버튼코트',
#   '캐미솔',
#   '더블버튼자켓',
#   '더블버튼코트',
#   '랩스커트',
#   '랩드레스',
#   '에코백',
#   '조거팬츠',
#   '클러치',
#   '볼레로',
#   '플레어스커트',
#   '플리츠스커트',
#   '비키니하의',
#   '아쿠아슈즈',
#   '크로스백',
#   '러플스커트',
#   '백팩',
#   '슬립온',
#   '벨트백',
#   '파우치백',
#   '메신저백',
#   '런닝화',
# ...
